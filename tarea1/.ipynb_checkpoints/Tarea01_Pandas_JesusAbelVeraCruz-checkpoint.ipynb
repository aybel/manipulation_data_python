# %%
# Tarea 01: Introducción a Pandas y exploración de datos
## Autor: Jesus Abel Vera Cruz

# %% [markdown]
# **Enunciado:**
# En un entorno de memoria restringida, ¿cómo cargarías eficientemente un
# archivo CSV de 100 GB que contiene un registro histórico de transacciones
# diarias, con el fin de calcular la suma total de las ventas globales?
#
# **Respuesta:**
# Para cargar un archivo CSV de 100 GB en un entorno con memoria restringida,
# una estrategia es utilizar el método de **lectura por fragmentos
# (chunking)**. Esta técnica consiste en:
#
# #importar la libreria panda
#
# import pandas as pd
#
# def calcular_suma_total(archivo_path,col_ventas, chunk_tam=100000):
#
#     """
#
#     Calcula la suma de ventas procesando el archivo en chunks.
#
#     Args:
#         archivo_path: Ruta al archivo CSV
#         col_ventas: Nombre de la columna con las ventas
#         chunk_tam: Número de filas por chunk (ajustable según memoria)
#     Returns:
#
#         Suma total de ventas
#     """
#     sumaTotal = 0
#
#     #Iteramos sobre los fragmentos del archivo
#     for chunk in pd.read_csv(
#         archivoPath,
#         chunkSize=chunk_tam,
#         usecols=[col_ventas],  # Solo cargar columna necesaria
#         dtype={col_ventas:'float64'},
#         low_memory=false
#     ):
#         #Sumamos las ventas del fragmento
#         sumaTotal += chunk[col_ventas].sum()
#     return sumaTotal
#
# ventasTotales=0
#
# ventasTotales=calcular_suma_total('archivo100gb.csv',col_ventas="monto_ventas",chunk_tam=50000)
#
# #imprmirmos el total
# print(f"Ventas totales: {ventasTotales:,.2f}")

# %%
## Ejercicio 2: Análisis exploratorio de datos con Pandas
### Enunciado:
### Crea un nuevo notrebook en Google Colab e importa la data “BD_Negocios_dos.csv” :
### df = pd.read_csv("/content/BD_Negocios_dos.csv", sep=";")

### -2.1 Realizar análisis exploratorio del dataset
### -2.2 Determinar distribución de clientes por tipo de local
### -2.3 Filtrar clientes con edad menor a 45 años

###  **Dataset:** BD_Negocios_dos.csv

### 2.1  Realizar análisis exploratorio del dataset
import pandas as pd
import numpy as np

df=pd.read_csv("BD_Negocios_Dos.csv")

print("=" * 60)
print("2.1. Análisis exploratorio del dataset")
print("=" * 60)
print("\n Dimensión del dataset:")
print(f"Filas: {df.shape[0]:,}")
print(f"Columnas: {df.shape[1]}")
print("\n Primeras 5 filas del Dataset:")
display(df.head())

print("\n Tipos de datos y memoria:")
df.info()
print("\n Descripción estadística de variables numéricas:")
display(df.describe())
print("\n Columnas del dataset:")
print(df.columns.tolist())

print("\n")

print("=" * 60)
print("2.2 Determinar distribución de clientes por tipo de local")
print("=" * 60)

#Agrupamos por tipolocal
distribucionClientesTipoLocal=df.groupby('tipolocal')['numdoc'].count().reset_index()
distribucionClientesTipoLocal.columns=['Tipo de local','Cantidad de clientes']
#Ordenamos de mayor a menor
distribucionClientesTipoLocal=distribucionClientesTipoLocal.sort_values('Cantidad de clientes',ascending=False)

print("\n Distribución de clientes por tipo de local:")
display(distribucionClientesTipoLocal)
  
print(f"\n Total de clientes: {distribucionClientesTipoLocal['Cantidad de clientes'].sum():,}")
print(f" Número de tipos de local: {len(distribucionClientesTipoLocal)}")

#Calculamos porcentajes 
distribucionClientesTipoLocal['Porcentaje (%)']=(distribucionClientesTipoLocal['Cantidad de clientes'] / 
                                                 distribucionClientesTipoLocal['Cantidad de clientes'].sum()*100).round(2)

printf("\n Distribución con porcentajes")
display(distribucionClientesTipoLocal)
# Out:
# ============================================================
# 2.1. Análisis exploratorio del dataset
# ============================================================
#
#  Dimensión del dataset:
# Filas: 44,507
# Columnas: 96
#
#  Primeras 5 filas del Dataset:
#    tipdoc    numdoc      fcre  monto_mes_ini  cuota_mes_ini  ncuota_mes_ini  \
# 0       1  10095961  20151117         1000.0         198.40               6
# 1       1  10116953  20120920         6000.0         615.99              12
# 2       1  10126150  20110726         6000.0         456.61              18
# 3       1  10147972  20090525        45000.0        4401.15              12
# 4       1  10155769  20150624         2000.0         215.20              12
#
#    tasa_mes_ini  saldo_mes_20151231  Flg_Refin_Jud_Cast_6m  per_perdida_6m  \
# 0          77.0              857.94                    0.0        201605.0
# 1          41.0            14387.79                    0.0        201606.0
# 2          48.0            13696.02                    0.0        201603.0
# 3          32.0             2887.50                    0.0        201602.0
# 4          60.0             1124.90                    0.0        201605.0
#
#    ...  lineaotroprod_csf_3um  otrosprod_csf_6um  lineaotroprod_csf_6um  \
# 0  ...                    NaN                  0                    NaN
# 1  ...                    NaN                  0                    NaN
# 2  ...                    NaN                  0                    NaN
# 3  ...                 7771.0                  1                 7771.0
# 4  ...                    NaN                  0                    NaN
#
#    ventas_mensual  patrimonio   tipolocal  tipoactividad  \
# 0         6000.00      8029.0  De Familia       Comercio
# 1        22928.57     35812.0  De Familia       Comercio
# 2        18000.00     50779.4  De Familia    Manufactura
# 3       123500.00    310536.8   Alquilado       Comercio
# 4         6000.00      7460.0      Propio       Comercio
#
#                actividadeconomica      tipovivienda  r_cuotapagada
# 0  VENTA P/MENOR ALIMENTOS BEBIDA        De Familia           0.17
# 1  VENTA AL POR MENOR DE OTROS PR        De Familia           0.06
# 2  ELABORACION DE PRODUCTOS DE PA        De Familia           0.50
# 3  VENTA AL POR MENOR DE OTROS PR  Propia Pagándola           0.83
# 4   VENTA AL POR MENOR EN PUESTOS        De Familia           0.50
#
# [5 rows x 96 columns]
#  Tipos de datos y memoria:
# <class 'pandas.DataFrame'>
# RangeIndex: 44507 entries, 0 to 44506
# Data columns (total 96 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tipdoc                 44507 non-null  int64
#  1   numdoc                 44507 non-null  int64
#  2   fcre                   44507 non-null  int64
#  3   monto_mes_ini          44507 non-null  float64
#  4   cuota_mes_ini          44507 non-null  float64
#  5   ncuota_mes_ini         44507 non-null  int64
#  6   tasa_mes_ini           44507 non-null  float64
#  7   saldo_mes_20151231     44507 non-null  float64
#  8   Flg_Refin_Jud_Cast_6m  16564 non-null  float64
#  9   per_perdida_6m         16564 non-null  float64
#  10  SALDO_ANTES_PERD_6m    16564 non-null  float64
#  11  recuperado_flg_6m      16564 non-null  float64
#  12  recuperado_periodo_6m  16564 non-null  float64
#  13  fuga_periodo_6m        16564 non-null  float64
#  14  fuga_periodo_6m_pp     16564 non-null  float64
#  15  ent_fuga_mes           10607 non-null  float64
#  16  clas_ent_fuga_mes      0 non-null      float64
#  17  ent_fuga_pp            4630 non-null   float64
#  18  clas_ent_fuga_pp       0 non-null      float64
#  19  target_6m              44507 non-null  int64
#  20  flg_usar               44507 non-null  int64
#  21  otro_mes_sf_act        44507 non-null  int64
#  22  otro_nentmes_sf_act    44507 non-null  int64
#  23  otro_lineames_sf_act   26712 non-null  float64
#  24  otro_pp_sf_act         44507 non-null  int64
#  25  otro_nentpp_sf_act     44507 non-null  int64
#  26  otro_lineapp_sf_act    7603 non-null   float64
#  27  otro_tc_sf_act         44507 non-null  int64
#  28  otro_nenttc_sf_act     44507 non-null  int64
#  29  otro_lineatc_sf_act    14962 non-null  float64
#  30  otro_mes_sf_3um        44507 non-null  int64
#  31  otro_nentmes_sf_3um    28126 non-null  float64
#  32  otro_lineames_sf_3um   28126 non-null  float64
#  33  otro_pp_sf_3um         44507 non-null  int64
#  34  otro_nentpp_sf_3um     8687 non-null   float64
#  35  otro_lineapp_sf_3um    8687 non-null   float64
#  36  otro_tc_sf_3um         44507 non-null  int64
#  37  otro_nenttc_sf_3um     44507 non-null  int64
#  38  otro_lineatc_sf_3um    15438 non-null  float64
#  39  otro_mes_sf_6um        44507 non-null  int64
#  40  otro_nentmes_sf_6um    44507 non-null  int64
#  41  otro_lineames_sf_6um   29124 non-null  float64
#  42  otro_pp_sf_6um         44507 non-null  int64
#  43  otro_nentpp_sf_6um     44507 non-null  int64
#  44  otro_lineapp_sf_6um    9599 non-null   float64
#  45  otro_tc_sf_6um         44507 non-null  int64
#  46  otro_nenttc_sf_6um     44507 non-null  int64
#  47  otro_lineatc_sf_6um    15886 non-null  float64
#  48  sexo                   44507 non-null  str
#  49  edad                   44507 non-null  int64
#  50  departamento           44493 non-null  str
#  51  estcivil               44455 non-null  str
#  52  gradoinst              43720 non-null  str
#  53  monto_mes_ult          44507 non-null  float64
#  54  cuota_mes_ult          44507 non-null  float64
#  55  ncuotas_mes_ult        44507 non-null  int64
#  56  CuotasPagadas_mes_ult  44507 non-null  int64
#  57  Tasa_mes_ult           44507 non-null  float64
#  58  fechadesembolso_ult    44507 non-null  int64
#  59  diasmora_mes_ult       44507 non-null  int64
#  60  meses_ult_desemb_mes   44507 non-null  int64
#  61  nro_desemb_mes         44484 non-null  float64
#  62  monto_tot_mes          44484 non-null  float64
#  63  monto_prom_mes         44484 non-null  float64
#  64  nro_desemb_pp          6007 non-null   float64
#  65  monto_tot_pp           6007 non-null   float64
#  66  monto_prom_pp          6007 non-null   float64
#  67  saldomes_peer_act      25104 non-null  float64
#  68  nent_me_peer_act       25104 non-null  float64
#  69  ratio_mes_peer_sf_act  44507 non-null  int64
#  70  saldomes_peer_3um      26524 non-null  float64
#  71  nent_me_peer_3um       26524 non-null  float64
#  72  ratio_mes_peer_sf_3um  44507 non-null  int64
#  73  saldomes_peer_6um      27538 non-null  float64
#  74  nent_me_peer_6um       27538 non-null  float64
#  75  ratio_mes_peer_sf_6um  44507 non-null  int64
#  76  nprod_sf_act           44507 non-null  int64
#  77  nprod_sf_3u            44507 non-null  int64
#  78  nprod_sf_6u            44507 non-null  int64
#  79  mesescte_csf           44493 non-null  float64
#  80  mesescte_mes           44484 non-null  float64
#  81  fingreso_csf           44493 non-null  float64
#  82  fingreso_mes           44484 non-null  float64
#  83  otrosprod_csf_act      44507 non-null  int64
#  84  lineaotroprod_csf_act  6229 non-null   float64
#  85  otrosprod_csf_3um      44507 non-null  int64
#  86  lineaotroprod_csf_3um  6277 non-null   float64
#  87  otrosprod_csf_6um      44507 non-null  int64
#  88  lineaotroprod_csf_6um  6187 non-null   float64
#  89  ventas_mensual         44347 non-null  float64
#  90  patrimonio             44501 non-null  float64
#  91  tipolocal              44229 non-null  str
#  92  tipoactividad          44498 non-null  str
#  93  actividadeconomica     44498 non-null  str
#  94  tipovivienda           43976 non-null  str
#  95  r_cuotapagada          43985 non-null  float64
# dtypes: float64(51), int64(37), str(8)
# memory usage: 32.6 MB
#
#  Descripción estadística de variables numéricas:
#              tipdoc        numdoc          fcre  monto_mes_ini  cuota_mes_ini  \
# count  44507.000000  4.450700e+04  4.450700e+04   44507.000000   44507.000000
# mean       1.000202  2.621515e+07  2.012968e+07   10344.414668     889.481000
# std        0.014219  1.824247e+07  2.110159e+04   13004.029032    1066.193175
# min        1.000000  3.130000e+02  2.009010e+07      29.300000       0.000000
# 25%        1.000000  9.662528e+06  2.011101e+07    3000.000000     320.800000
# 50%        1.000000  2.314344e+07  2.014031e+07    5039.200000     525.690000
# 75%        1.000000  4.179836e+07  2.015041e+07   10156.800000    1027.400000
# max        2.000000  8.068897e+07  2.015123e+07  195602.940000   47801.520000
#
#        ncuota_mes_ini  tasa_mes_ini  saldo_mes_20151231  \
# count    44507.000000  44507.000000        44507.000000
# mean        13.736221     48.773791         9632.544903
# std          5.176842     12.776489        12925.893238
# min          0.000000      0.000000            7.860000
# 25%         12.000000     40.000000         1926.040000
# 50%         12.000000     47.000000         4825.790000
# 75%         18.000000     58.000000        12180.210000
# max         84.000000    126.000000       366125.512000
#
#        Flg_Refin_Jud_Cast_6m  per_perdida_6m  ...  fingreso_mes  \
# count                16564.0    16564.000000  ...  4.448400e+04
# mean                     0.0   201603.627143  ...  2.012967e+07
# std                      0.0        1.636156  ...  2.110215e+04
# min                      0.0   201601.000000  ...  2.009010e+07
# 25%                      0.0   201602.000000  ...  2.011101e+07
# 50%                      0.0   201604.000000  ...  2.014031e+07
# 75%                      0.0   201605.000000  ...  2.015041e+07
# max                      0.0   201606.000000  ...  2.015123e+07
#
#        otrosprod_csf_act  lineaotroprod_csf_act  otrosprod_csf_3um  \
# count       44507.000000            6229.000000       44507.000000
# mean            0.139956            3176.435383           0.141034
# std             0.346945            4278.646229           0.348061
# min             0.000000               0.000000           0.000000
# 25%             0.000000               3.000000           0.000000
# 50%             0.000000            1951.000000           0.000000
# 75%             0.000000            4151.000000           0.000000
# max             1.000000           39500.000000           1.000000
#
#        lineaotroprod_csf_3um  otrosprod_csf_6um  lineaotroprod_csf_6um  \
# count            6277.000000       44507.000000            6187.000000
# mean             3344.649036           0.139012            3417.752384
# std              4591.450785           0.345963            4794.811369
# min                 0.000000           0.000000               0.000000
# 25%               249.000000           0.000000             250.500000
# 50%              2000.000000           0.000000            2000.000000
# 75%              4349.000000           0.000000            4369.000000
# max             44703.000000           1.000000           47141.000000
#
#        ventas_mensual    patrimonio  r_cuotapagada
# count    4.434700e+04  4.450100e+04   43985.000000
# mean     3.133744e+04  7.006111e+04       0.425461
# std      5.122265e+04  1.345802e+05       0.277909
# min      0.000000e+00 -2.341940e+05       0.000000
# 25%      8.200000e+03  1.508050e+04       0.170000
# 50%      1.580000e+04  3.385200e+04       0.420000
# 75%      3.389999e+04  7.629500e+04       0.670000
# max      1.863333e+06  5.895222e+06       1.000000
#
# [8 rows x 88 columns]
#  Columnas del dataset:
# ['tipdoc', 'numdoc', 'fcre', 'monto_mes_ini', 'cuota_mes_ini', 'ncuota_mes_ini', 'tasa_mes_ini', 'saldo_mes_20151231', 'Flg_Refin_Jud_Cast_6m', 'per_perdida_6m', 'SALDO_ANTES_PERD_6m', 'recuperado_flg_6m', 'recuperado_periodo_6m', 'fuga_periodo_6m', 'fuga_periodo_6m_pp', 'ent_fuga_mes', 'clas_ent_fuga_mes', 'ent_fuga_pp', 'clas_ent_fuga_pp', 'target_6m', 'flg_usar', 'otro_mes_sf_act', 'otro_nentmes_sf_act', 'otro_lineames_sf_act', 'otro_pp_sf_act', 'otro_nentpp_sf_act', 'otro_lineapp_sf_act', 'otro_tc_sf_act', 'otro_nenttc_sf_act', 'otro_lineatc_sf_act', 'otro_mes_sf_3um', 'otro_nentmes_sf_3um', 'otro_lineames_sf_3um', 'otro_pp_sf_3um', 'otro_nentpp_sf_3um', 'otro_lineapp_sf_3um', 'otro_tc_sf_3um', 'otro_nenttc_sf_3um', 'otro_lineatc_sf_3um', 'otro_mes_sf_6um', 'otro_nentmes_sf_6um', 'otro_lineames_sf_6um', 'otro_pp_sf_6um', 'otro_nentpp_sf_6um', 'otro_lineapp_sf_6um', 'otro_tc_sf_6um', 'otro_nenttc_sf_6um', 'otro_lineatc_sf_6um', 'sexo', 'edad', 'departamento', 'estcivil', 'gradoinst', 'monto_mes_ult', 'cuota_mes_ult', 'ncuotas_mes_ult', 'CuotasPagadas_mes_ult', 'Tasa_mes_ult', 'fechadesembolso_ult', 'diasmora_mes_ult', 'meses_ult_desemb_mes', 'nro_desemb_mes', 'monto_tot_mes', 'monto_prom_mes', 'nro_desemb_pp', 'monto_tot_pp', 'monto_prom_pp', 'saldomes_peer_act', 'nent_me_peer_act', 'ratio_mes_peer_sf_act', 'saldomes_peer_3um', 'nent_me_peer_3um', 'ratio_mes_peer_sf_3um', 'saldomes_peer_6um', 'nent_me_peer_6um', 'ratio_mes_peer_sf_6um', 'nprod_sf_act', 'nprod_sf_3u', 'nprod_sf_6u', 'mesescte_csf', 'mesescte_mes', 'fingreso_csf', 'fingreso_mes', 'otrosprod_csf_act', 'lineaotroprod_csf_act', 'otrosprod_csf_3um', 'lineaotroprod_csf_3um', 'otrosprod_csf_6um', 'lineaotroprod_csf_6um', 'ventas_mensual', 'patrimonio', 'tipolocal', 'tipoactividad', 'actividadeconomica', 'tipovivienda', 'r_cuotapagada']
#
#
# ============================================================
# 2.2 Determinar distribución de clientes por tipo de local
# ============================================================
#
#  DISTRIBUCIÓN DE CLIENTES POR TIPO DE LOCAL:
#   Tipo de local  Cantidad de clientes
# 2        Propio                 18478
# 0     Alquilado                 18253
# 1    De Familia                  7498
#  Total de clientes: 44,229
#  Número de tipos de local: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 55
#      51
#      52 #Calculamos porcentajes
#      53 distribucionClientesTipoLocal['Porcentaje (%)']=(distribucionClientesTipoLocal['Cantidad de clientes']/distribucionClientesTipoLocal['Cantidad de clientes'].sum()*100).round(2)
#      54
# ---> 55 printf(f"\n Distrubución con porcentajes")
#      56 display(distribucionClientesTipoLocal)
#
# NameError: name 'printf' is not defined
